# %% [markdown]
# ## Cleaner pipeline

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
data_raw = pd.read_excel("Логи.xlsx")
data_raw.head()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-4-c436332ed6a9> in <cell line: 1>()
# ----> 1 data_raw = pd.read_excel("Логи.xlsx")
#       2 data_raw.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480     if not isinstance(io, ExcelFile):
#     481         should_close = True
# --> 482         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483     elif engine and engine != io.engine:
#     484         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1650                 ext = "xls"
#    1651             else:
# -> 1652                 ext = inspect_excel_format(
#    1653                     content_or_path=path_or_buffer, storage_options=storage_options
#    1654                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1541             return None
#    1542
# -> 1543         with zipfile.ZipFile(stream) as zf:
#    1544             # Workaround for some third party files that use forward slashes and
#    1545             # lower case names.
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1267         try:
#    1268             if mode == 'r':
# -> 1269                 self._RealGetContents()
#    1270             elif mode in ('w', 'x'):
#    1271                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.10/zipfile.py in _RealGetContents(self)
#    1334             raise BadZipFile("File is not a zip file")
#    1335         if not endrec:
# -> 1336             raise BadZipFile("File is not a zip file")
#    1337         if self.debug > 1:
#    1338             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
ERROR_STEMS = [
        # internal
        "Данные не могут быть обработаны по причине",
        "Произошла ошибка импорта",
        "Данные не могут быть проимпортированы по причине",

        # common
        "Connection ID",
        "Execution Timeout Expired",
        "Unable to parse request",
        "Unable to process",
        "Unable to send",
        "Unhandled error",
        "Для команды интеграции",
        "Ошибка обработки события",
        "Ошибка при обращении к сервису ЕИС",
        "Проверка приглашений",
        "Событие обработано с ошибками",
        "Exception while Executing",


        # Database
        "An exception occurred in the database while saving changes",
        "An exception occurred while iterating over the results of a query",
        "Could not execute query",
        "Could not execute command",
        "Execution error",
        "Failed executing DbCommand",
        "Failed to execute query batch",
        "NHibernate.Exceptions.GenericADOException",
        "The database operation was expected",


        # Operations
        "OpComplete",
        "System.InvalidOperationException",

        # RabbitMQ
        "R-FAULT rabbitmq",
        "S-FAULT rabbitmq",
        "Ошибка при обработке запроса",
        "Ошибка при обработке события",
        "Ошибка публикации события",

        # МЧД ошибки
        "МЧД",
        "Необработанная ошибка валидации МЧД"
    ]

# %%
ERROR_STEMS

# %%
def print_whole_df(df):
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
        print(df)

# %%
import re

def replace_parameters(x: str):
    return re.sub(r'[\:\=]\s?[^\,\]\s]+', '', x)

def apply_stemming(x: str):
    for stem in ERROR_STEMS:
        if x.startswith(stem):
            return stem
    return x

# %%
data_raw['log_short'] = data_raw['log'].apply(replace_parameters).apply(apply_stemming)

# %%
len(data_raw['log_short'].unique())

# %%
print_whole_df(data_raw['log_short'].value_counts())

# %%
data_raw['log_short'].value_counts().to_csv("reduced_stemmed_paramed_logs.csv", encoding='utf-8-sig')

# %%
data_raw.head()

# %%
data_raw.to_csv("logs_with_short.csv", encoding="utf-8-sig")

# %% [markdown]
# ## Lookup Table rework

# %%
look_up_table_old = pd.read_excel("ErrorLookUpTable.xlsx")
look_up_table_old.head()
# Out:
#                   Коммуникации с внешними системами  \
# 0  Данные не могут быть проимпортированы по причине
# 1                   Unable to get integration token
# 2                                    Unable to send
# 3       Ошибка получения файлов из каталога nsi ЕИС
# 4                                  S-FAULT rabbitmq
#
#                           Ошибка внутренних сервисов  \
# 0                                    Execution error
# 1  Ошибка обработки запроса на регистрацию/измене...
# 2                          Execution Timeout Expired
# 3                       The wait operation timed out
# 4  Pp3.Contracts.Dto.Contract.Action.ContractActi...
#
#                                            Ошибки БД  \
# 0                            Could not execute query
# 1                         Failed executing DbCommand
# 2  An exception occurred while iterating over the...
# 3                      Failed to execute query batch
# 4                                 Unable to get data
#
#                                   Неизвестная ошибка  \
# 0                           Unexpected error occured
# 1                              Exception SendCommand
# 2  Ошибка выполнения подписчика на событие заверш...
# 3                                          job error
# 4                                    Unhandled error
#
#                                  Не ошибка  \
# 0           Immediate job execution failed
# 1             Response already has started
# 2  Ошибка при расчёте достижений компании.
# 3                                      NaN
# 4                                      NaN
#
#                       Ошибка валидации
# 0                                  МЧД
# 1  Необработанная ошибка валидации МЧД
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN

# %%
logs_classes = look_up_table_old.columns
index2class = {i: v for (i, v) in enumerate(logs_classes)}
class2index = {v: k for (k, v) in index2class.items()}

# %%
index2class, class2index
# Out:
# ({0: 'Коммуникации с внешними системами',
#   1: 'Ошибка внутренних сервисов',
#   2: 'Ошибки БД',
#   3: 'Неизвестная ошибка',
#   4: 'Не ошибка',
#   5: 'Ошибка валидации'},
#  {'Коммуникации с внешними системами': 0,
#   'Ошибка внутренних сервисов': 1,
#   'Ошибки БД': 2,
#   'Неизвестная ошибка': 3,
#   'Не ошибка': 4,
#   'Ошибка валидации': 5})

# %%
logtype2class_index = {logtype: class2index[log_class] for log_class in logs_classes for logtype in look_up_table_old[log_class] if logtype is not np.nan}
logtype2class_index
# Out:
# {'Данные не могут быть проимпортированы по причине': 0,
#  'Unable to get integration token': 0,
#  'Unable to send': 0,
#  'Ошибка получения файлов из каталога nsi ЕИС': 0,
#  'S-FAULT rabbitmq': 0,
#  'Ошибка при обработке события': 0,
#  'Невозможно запросить данные из УАС': 0,
#  'Ошибка запроса данных из УАС': 0,
#  'R-FAULT rabbitmq': 0,
#  'Невозможно скачать файл по ссылке': 0,
#  'Ошибка авторизации в интеграционном апи': 0,
#  'Не найден КПГЗ': 0,
#  'Unable to upload files': 0,
#  'Ошибка запроса статуса самозанятого': 0,
#  'Произошла ошибка импорта': 0,
#  'Для команды интеграции': 0,
#  'Unable to parse request': 0,
#  'Архив (УАС) не загрузился/не загружался': 0,
#  'NHibernate.Exceptions.GenericADOException': 0,
#  'Kaluga workflowId, Сессия умерла': 0,
#  'Ошибка обращения к api внешней системы ЕГРЮЛ ДИТ': 0,
#  'Ошибка при вызове сервиса ЕИС': 0,
#  'Ошибка при запросе списка интеграционного обмена.': 0,
#  'Не удалось скачать файл из ЕИС по ссылке': 0,
#  'Unable to set failed for command, type': 0,
#  'Ошибка доступа к сервису капчи': 0,
#  'Execution error': 1,
#  'Ошибка обработки запроса на регистрацию/изменение данных компании': 1,
#  'Execution Timeout Expired': 1,
#  'The wait operation timed out': 1,
#  'Pp3.Contracts.Dto.Contract.Action.ContractActionException': 1,
#  'Данные не могут быть обработаны по причине': 1,
#  'Unable to process': 1,
#  'Kaluga workflowId': 1,
#  'Unable to verify and save signature': 1,
#  'Ошибка при опросе очереди результатов подписания поставщиком в ЕИС': 1,
#  'System.InvalidOperationException': 1,
#  'Ошибка обработки события': 1,
#  'Ошибка актуализации блокировок компании': 1,
#  'Не найдена компания с идентификатором': 1,
#  'Unable to SendResult CreateAuction OpId': 1,
#  "'_x0002_', hexadecimal value 0x02, is an invalid character.": 1,
#  'Файл с fileId, filePath отстутствует на диске': 1,
#  'OpComplete': 1,
#  'An error has occurred in the task of cleaning': 1,
#  'Ошибка при поиске неиндексированных': 1,
#  'Ошибка при расчёте достижений компании.': 4,
#  'Ошибка индексации оферт': 1,
#  'Ошибка запроса получения информации об операции интеграции': 1,
#  'An exception was thrown during execution': 1,
#  'Exception while Executing': 1,
#  'Событие обработано с ошибками': 1,
#  'Реиндексация компаний завершилась с ошибкой': 1,
#  'Ошибка публикации события': 1,
#  'Could not execute query': 2,
#  'Failed executing DbCommand': 2,
#  'An exception occurred while iterating over the results of a query': 2,
#  'Failed to execute query batch': 2,
#  'Unable to get data': 2,
#  'Could not execute command': 2,
#  'An error occurred during stat collection': 2,
#  'Could not synchronize database state with session': 2,
#  'An exception occurred in the database': 2,
#  'Ошибка при обработке запроса': 2,
#  'The database operation was expected': 2,
#  'Unexpected error occured': 3,
#  'Exception SendCommand': 3,
#  'Ошибка выполнения подписчика на событие завершения применения транзакции': 3,
#  'job error': 3,
#  'Unhandled error': 3,
#  'Unhandled exception': 3,
#  'Проверка приглашений': 3,
#  'Connection ID': 3,
#  'Exception occurred while processing message.': 3,
#  'The handle is invalid._x000D_\n': 3,
#  'Unable to execute command': 3,
#  "Failed to invoke hub method 'joinGroup'.": 3,
#  'An unhandled exception has occurred while executing the request.': 3,
#  'Immediate job execution failed': 4,
#  'Response already has started': 4,
#  'МЧД': 5,
#  'Необработанная ошибка валидации МЧД': 5}

# %%
logtype2class_name = {k: index2class[v] for (k, v) in logtype2class_index.items()}
logtype2class_name
# Out:
# {'Данные не могут быть проимпортированы по причине': 'Коммуникации с внешними системами',
#  'Unable to get integration token': 'Коммуникации с внешними системами',
#  'Unable to send': 'Коммуникации с внешними системами',
#  'Ошибка получения файлов из каталога nsi ЕИС': 'Коммуникации с внешними системами',
#  'S-FAULT rabbitmq': 'Коммуникации с внешними системами',
#  'Ошибка при обработке события': 'Коммуникации с внешними системами',
#  'Невозможно запросить данные из УАС': 'Коммуникации с внешними системами',
#  'Ошибка запроса данных из УАС': 'Коммуникации с внешними системами',
#  'R-FAULT rabbitmq': 'Коммуникации с внешними системами',
#  'Невозможно скачать файл по ссылке': 'Коммуникации с внешними системами',
#  'Ошибка авторизации в интеграционном апи': 'Коммуникации с внешними системами',
#  'Не найден КПГЗ': 'Коммуникации с внешними системами',
#  'Unable to upload files': 'Коммуникации с внешними системами',
#  'Ошибка запроса статуса самозанятого': 'Коммуникации с внешними системами',
#  'Произошла ошибка импорта': 'Коммуникации с внешними системами',
#  'Для команды интеграции': 'Коммуникации с внешними системами',
#  'Unable to parse request': 'Коммуникации с внешними системами',
#  'Архив (УАС) не загрузился/не загружался': 'Коммуникации с внешними системами',
#  'NHibernate.Exceptions.GenericADOException': 'Коммуникации с внешними системами',
#  'Kaluga workflowId, Сессия умерла': 'Коммуникации с внешними системами',
#  'Ошибка обращения к api внешней системы ЕГРЮЛ ДИТ': 'Коммуникации с внешними системами',
#  'Ошибка при вызове сервиса ЕИС': 'Коммуникации с внешними системами',
#  'Ошибка при запросе списка интеграционного обмена.': 'Коммуникации с внешними системами',
#  'Не удалось скачать файл из ЕИС по ссылке': 'Коммуникации с внешними системами',
#  'Unable to set failed for command, type': 'Коммуникации с внешними системами',
#  'Ошибка доступа к сервису капчи': 'Коммуникации с внешними системами',
#  'Execution error': 'Ошибка внутренних сервисов',
#  'Ошибка обработки запроса на регистрацию/изменение данных компании': 'Ошибка внутренних сервисов',
#  'Execution Timeout Expired': 'Ошибка внутренних сервисов',
#  'The wait operation timed out': 'Ошибка внутренних сервисов',
#  'Pp3.Contracts.Dto.Contract.Action.ContractActionException': 'Ошибка внутренних сервисов',
#  'Данные не могут быть обработаны по причине': 'Ошибка внутренних сервисов',
#  'Unable to process': 'Ошибка внутренних сервисов',
#  'Kaluga workflowId': 'Ошибка внутренних сервисов',
#  'Unable to verify and save signature': 'Ошибка внутренних сервисов',
#  'Ошибка при опросе очереди результатов подписания поставщиком в ЕИС': 'Ошибка внутренних сервисов',
#  'System.InvalidOperationException': 'Ошибка внутренних сервисов',
#  'Ошибка обработки события': 'Ошибка внутренних сервисов',
#  'Ошибка актуализации блокировок компании': 'Ошибка внутренних сервисов',
#  'Не найдена компания с идентификатором': 'Ошибка внутренних сервисов',
#  'Unable to SendResult CreateAuction OpId': 'Ошибка внутренних сервисов',
#  "'_x0002_', hexadecimal value 0x02, is an invalid character.": 'Ошибка внутренних сервисов',
#  'Файл с fileId, filePath отстутствует на диске': 'Ошибка внутренних сервисов',
#  'OpComplete': 'Ошибка внутренних сервисов',
#  'An error has occurred in the task of cleaning': 'Ошибка внутренних сервисов',
#  'Ошибка при поиске неиндексированных': 'Ошибка внутренних сервисов',
#  'Ошибка при расчёте достижений компании.': 'Не ошибка',
#  'Ошибка индексации оферт': 'Ошибка внутренних сервисов',
#  'Ошибка запроса получения информации об операции интеграции': 'Ошибка внутренних сервисов',
#  'An exception was thrown during execution': 'Ошибка внутренних сервисов',
#  'Exception while Executing': 'Ошибка внутренних сервисов',
#  'Событие обработано с ошибками': 'Ошибка внутренних сервисов',
#  'Реиндексация компаний завершилась с ошибкой': 'Ошибка внутренних сервисов',
#  'Ошибка публикации события': 'Ошибка внутренних сервисов',
#  'Could not execute query': 'Ошибки БД',
#  'Failed executing DbCommand': 'Ошибки БД',
#  'An exception occurred while iterating over the results of a query': 'Ошибки БД',
#  'Failed to execute query batch': 'Ошибки БД',
#  'Unable to get data': 'Ошибки БД',
#  'Could not execute command': 'Ошибки БД',
#  'An error occurred during stat collection': 'Ошибки БД',
#  'Could not synchronize database state with session': 'Ошибки БД',
#  'An exception occurred in the database': 'Ошибки БД',
#  'Ошибка при обработке запроса': 'Ошибки БД',
#  'The database operation was expected': 'Ошибки БД',
#  'Unexpected error occured': 'Неизвестная ошибка',
#  'Exception SendCommand': 'Неизвестная ошибка',
#  'Ошибка выполнения подписчика на событие завершения применения транзакции': 'Неизвестная ошибка',
#  'job error': 'Неизвестная ошибка',
#  'Unhandled error': 'Неизвестная ошибка',
#  'Unhandled exception': 'Неизвестная ошибка',
#  'Проверка приглашений': 'Неизвестная ошибка',
#  'Connection ID': 'Неизвестная ошибка',
#  'Exception occurred while processing message.': 'Неизвестная ошибка',
#  'The handle is invalid._x000D_\n': 'Неизвестная ошибка',
#  'Unable to execute command': 'Неизвестная ошибка',
#  "Failed to invoke hub method 'joinGroup'.": 'Неизвестная ошибка',
#  'An unhandled exception has occurred while executing the request.': 'Неизвестная ошибка',
#  'Immediate job execution failed': 'Не ошибка',
#  'Response already has started': 'Не ошибка',
#  'МЧД': 'Ошибка валидации',
#  'Необработанная ошибка валидации МЧД': 'Ошибка валидации'}

# %% [markdown]
# ### Dump jsons

# %%
import json

# %%
def write_json(obj, fname):
    with open(fname, 'w') as f:
        s = json.dumps(obj, indent=4, ensure_ascii=False)
        f.write(s)

# %%
write_json(index2class, "class_index2class_name.json")
write_json(logtype2class_index, "log_type2class_index.json")

# %% [markdown]
# ## Classifier

# %%
import json
import re
from dataclasses import dataclass


@dataclass
class LogInfo:
    log_type: str
    cat_name: str


class LogClassifier:
    def __init__(self):
        self.index2class = json.loads(open("class_index2class_name.json", 'r').read())
        self.logtype2class_index = json.loads(open("log_type2class_index.json", 'r').read())
        self.unk = 'Unhandled error'

    def replace_parameters(self, x: str):
        return re.sub(r'[\:\=]\s?[^\,\]\s]+', '', x)

    def apply_stemming(self, x: str):
        for stem in self.logtype2class_index.keys():
            if x.startswith(stem):
                return stem
        return self.unk

    def process_raw(self, log_s: str):
        return self.apply_stemming(self.replace_parameters(log_s))

    def predict(self, log_s: str):
        log_type = self.process_raw(log_s)
        cat_id = self.logtype2class_index[log_type]
        cat_name = self.index2class[str(cat_id)]

        return LogInfo(log_type, cat_name)

# %%
cls = LogClassifier()

# %%
cls.predict('The wait operation timed out')
# Out:
# LogInfo(log_type='The wait operation timed out', cat_name='Ошибка внутренних сервисов')

# %% [markdown]
# ## Torture data a little bit more

# %%
import numpy as np
import pandas as pd
import nltk
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt

# %%
def replace_parameters(x: str):
    return re.sub(r'[\:\=]\s?[^\,\]\s]+', '', x)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
data = pd.read_excel("Логи.xlsx")

# %%
data.head()
# Out:
#                                  id          create_date  \
# 0  6424198940e01f33f8b596fa9fe7391c  2023-10-09 00:00:01
# 1  9851574021c269d401accc3a1381259a  2023-10-09 00:00:02
# 2  35f4f5fc4fdd12717347c2064729930e  2023-10-09 00:00:02
# 3  49f9dc2cb58ab8db9f59b2487fbe0768  2023-10-09 00:00:02
# 4  4f4830735dfc264fb40d1424e3e02bb2  2023-10-09 00:00:08
#
#                                                  log
# 0                    Unable to get integration token
# 1                    Unable to get integration token
# 2                    Unable to get integration token
# 3                    Unable to get integration token
# 4  Pp3.Contracts.Dto.Contract.Action.ContractActi...

# %%
data['create_date'] = pd.to_datetime(data['create_date'])

# %%
data['logs_without_params'] = data['log'].apply(replace_parameters)

# %%
from nltk.tokenize import wordpunct_tokenize
from nltk.corpus import stopwords

sw = set(stopwords.words('english') + stopwords.words('russian'))

def tokenize(sent):
    return wordpunct_tokenize(sent)

def ishex(s):
    return not set(s) - set("abcdef0123456789")

def remove_words(sent):
    return [w for w in sent if w not in sw and not ishex(w) and any(c.isalpha() for c in w)]

def process_corpus(corpus):
    tokenized = [tokenize(sent) for sent in tqdm(corpus, desc="Tokenization")]
    clean_corpus = [remove_words(sent) for sent in tqdm(tokenized, desc="Removing words")]
    return clean_corpus

corpus = data['logs_without_params'].str.lower().to_list()
clean_corpus = process_corpus(corpus)
# Out:
# Tokenization:   0%|          | 0/88855 [00:00<?, ?it/s]
# Removing stopwords:  68%|██████▊   | 60154/88855 [25:22<12:06, 39.50it/s]
# Removing words:   0%|          | 0/88855 [00:00<?, ?it/s]

# %%
from collections import Counter

counter = Counter()

for sent in tqdm(clean_corpus, desc="Creating vocab"):
    counter.update(sent)
# Out:
# Creating vocab:   0%|          | 0/88855 [00:00<?, ?it/s]

# %%
def build_vocab(counter: Counter, min_freq=3):
    most_common = counter.most_common()
    vocab = set([word for (word, freq) in most_common if freq >= min_freq])
    return vocab

# %%
counter.most_common()
# Out:
# [('данные', 46145),
#  ('причине', 46116),
#  ('могут', 46067),
#  ('packagedatetime', 45978),
#  ('packageguid', 45976),
#  ('сущности', 45962),
#  ('импортирована', 45961),
#  ('поздняя', 45961),
#  ('версия', 45961),
#  ('проимпортированы', 44392),
#  ('this_', 34124),
#  ('id', 18828),
#  ('offer0_', 13970),
#  ('join', 13439),
#  ('reg2_', 12867),
#  ('execution', 12752),
#  ('inner', 12062),
#  ('operation', 10264),
#  ('timeout', 10175),
#  ('error', 8684),
#  ('this_0_', 8611),
#  ('type', 8433),
#  ('job', 8396),
#  ('deleted', 7638),
#  ('ошибка', 7354),
#  ('contract', 7349),
#  ('key', 6787),
#  ('args', 6783),
#  ('y0_', 6618),
#  ('запроса', 6471),
#  ('обработки', 6469),
#  ('компании', 6458),
#  ('данных', 6452),
#  ('изменение', 6431),
#  ('регистрацию', 6403),
#  ('unable', 5669),
#  ('query', 5642),
#  ('execute', 5450),
#  ('could', 5374),
#  ('cast', 5099),
#  ('completion', 5086),
#  ('expired', 5072),
#  ('period', 5072),
#  ('elapsed', 5072),
#  ('prior', 5072),
#  ('server', 5072),
#  ('responding', 5072),
#  ('wait', 5070),
#  ('timed', 5070),
#  ('hierarchyleft', 5008),
#  ('hierarchyright', 5008),
#  ('entitystate', 4850),
#  ('conclusiondate', 4786),
#  ('aggregatedate', 4448),
#  ('aggregatetype', 4348),
#  ('decimal', 4251),
#  ('buyer1_', 4095),
#  ('contractstateid', 3988),
#  ('group', 3972),
#  ('company', 3942),
#  ('entityid', 3843),
#  ('p2', 3826),
#  ('pp3', 3794),
#  ('count', 3640),
#  ('contracts', 3624),
#  ('dto', 3599),
#  ('action', 3589),
#  ('get', 3567),
#  ('contractactionexception', 3458),
#  ('автоматическому', 3458),
#  ('отказу', 3458),
#  ('разрешено', 3458),
#  ('region', 3394),
#  ('regionid', 3380),
#  ('contract1_', 3285),
#  ('_x000d_', 3263),
#  ('y1_', 3242),
#  ('p1', 3099),
#  ('p3', 3093),
#  ('production1_', 3071),
#  ('buyerid', 3063),
#  ('null', 3043),
#  ('p6', 3025),
#  ('mindate', 3006),
#  ('y2_', 2979),
#  ('rows', 2936),
#  ('p5', 2866),
#  ('reg3_', 2863),
#  ('treepathid', 2859),
#  ('sum', 2810),
#  ('company1_', 2716),
#  ('select', 2628),
#  ('exists', 2425),
#  ('comp1_', 2404),
#  ('rubsum', 2367),
#  ('federallawid', 2361),
#  ('p4', 2285),
#  ('like', 2283),
#  ('integration', 2163),
#  ('contractid', 2141),
#  ('token', 2121),
#  ('sku0_', 2087),
#  ('seller5_', 2051),
#  ('conclusionreasonid', 1966),
#  ('sku3_', 1915),
#  ('command', 1900),
#  ('supplierid', 1893),
#  ('name', 1793),
#  ('contractitem', 1752),
#  ('event', 1742),
#  ('обработаны', 1675),
#  ('process', 1665),
#  ('nhibernate', 1644),
#  ('p0', 1611),
#  ('p11', 1603),
#  ('reg5_', 1596),
#  ('offer', 1503),
#  ('order', 1487),
#  ('offset', 1468),
#  ('fetch', 1468),
#  ('first', 1463),
#  ('p7', 1450),
#  ('object', 1441),
#  ('coalesce', 1428),
#  ('left', 1414),
#  ('auc1_', 1385),
#  ('outer', 1357),
#  ('sessionid', 1355),
#  ('kaluga', 1354),
#  ('workflowid', 1354),
#  ('contract2_', 1350),
#  ('workflow', 1348),
#  ('documents', 1348),
#  ('unexpected', 1346),
#  ('occured', 1346),
#  ('ci2_', 1292),
#  ('desc', 1263),
#  ('stateid', 1217),
#  ('ci1_', 1178),
#  ('supp4_', 1172),
#  ('shortname', 1165),
#  ('reg1_', 1155),
#  ('auctionid', 1124),
#  ('cust2_', 1115),
#  ('companyid', 1088),
#  ('offerstateid', 1024),
#  ('productiondirectoryid', 1018),
#  ('system', 999),
#  ('y3_', 959),
#  ('default', 938),
#  ('p10', 922),
#  ('failed', 910),
#  ('auction', 900),
#  ('sku', 899),
#  ('supplier', 862),
#  ('advanced', 830),
#  ('production4_', 813),
#  ('auctionitem', 812),
#  ('p8', 806),
#  ('productiondirectory', 772),
#  ('data', 770),
#  ('auction0_', 769),
#  ('offercount', 743),
#  ('createdofferid', 715),
#  ('granit', 711),
#  ('immediate', 697),
#  ('trying', 697),
#  ('enqueue', 697),
#  ('offer2_', 692),
#  ('exception', 692),
#  ('end', 689),
#  ('distinct', 688),
#  ('interceptors', 670),
#  ('subject', 663),
#  ('col_0_0_', 645),
#  ('customerid', 611),
#  ('offerid', 605),
#  ('customer', 599),
#  ('cc2_', 598),
#  ('microsoft', 597),
#  ('else', 594),
#  ('supplierca1_', 593),
#  ('cancellationtoken', 583),
#  ('case', 574),
#  ('skuid', 546),
#  ('onflushdirty', 536),
#  ('defaultflushentityeventlistener', 536),
#  ('need', 536),
#  ('supplier2_', 526),
#  ('comp2_', 494),
#  ('int', 486),
#  ('dbo', 486),
#  ('cc3_', 480),
#  ('b__0', 478),
#  ('p9', 468),
#  ('contractit1_', 456),
#  ('company4_', 456),
#  ('createdbys3_', 456),
#  ('code', 451),
#  ('createdate', 445),
#  ('offerenddate', 444),
#  ('suppliercatalogitemid', 440),
#  ('o1x5_', 432),
#  ('o2x6_', 432),
#  ('convert', 420),
#  ('substring', 420),
#  ('startcost', 419),
#  ('col_1_0_', 416),
#  ('core', 411),
#  ('entity', 405),
#  ('flushentityevent', 402),
#  ('flushevent', 402),
#  ('entityframeworkcore', 396),
#  ('internal', 383),
#  ('spuser', 381),
#  ('tender0_', 374),
#  ('contract0_', 372),
#  ('creationtime', 361),
#  ('willbearchived', 360),
#  ('auctionbet1_', 357),
#  ('description', 355),
#  ('transaction', 350),
#  ('year', 350),
#  ('month', 350),
#  ('overpriceid', 350),
#  ('событие', 339),
#  ('выполнения', 338),
#  ('подписчика', 338),
#  ('завершения', 338),
#  ('применения', 338),
#  ('транзакции', 338),
#  ('handleoutbound', 338),
#  ('string', 337),
#  ('bigint', 330),
#  ('sendcommand', 329),
#  ('inn', 311),
#  ('offeroverp1_', 310),
#  ('this_0_0_', 306),
#  ('systemuserid', 305),
#  ('cssp', 303),
#  ('occurred', 303),
#  ('unhandled', 301),
#  ('еис', 296),
#  ('suppliercatalogitem', 293),
#  ('send', 292),
#  ('varchar', 281),
#  ('impl', 280),
#  ('func', 274),
#  ('sessionimpl', 274),
#  ('purchaserequest', 273),
#  ('needreindex', 272),
#  ('p12', 270),
#  ('orm', 268),
#  ('purchaserequestinterceptor', 268),
#  ('currentstate', 268),
#  ('previousstate', 268),
#  ('propertynames', 268),
#  ('itype', 268),
#  ('types', 268),
#  ('compositeinterceptor', 268),
#  ('abstractflushingeventlistener', 268),
#  ('getcontractactionsforautofulldeny', 258),
#  ('sqlclient', 258),
#  ('opid', 255),
#  ('boolean', 254),
#  ('sourcefileid', 253),
#  ('createauction', 249),
#  ('sku1_', 246),
#  ('spgzid', 245),
#  ('userid', 244),
#  ('okpdid', 243),
#  ('productionid', 243),
#  ('barcode', 242),
#  ('gostclassificationjson', 242),
#  ('modelname', 242),
#  ('partnumber', 242),
#  ('manufacturerid', 242),
#  ('okeiid', 242),
#  ('oksmid', 242),
#  ('givingdate', 241),
#  ('number', 240),
#  ('asc', 234),
#  ('external', 228),
#  ('contractexecution', 228),
#  ('need1_', 226),
#  ('pp2', 221),
#  ('models', 221),
#  ('region3_', 219),
#  ('offer1_', 215),
#  ('externalsystemid', 211),
#  ('modifytime', 210),
#  ('contractaction', 204),
#  ('offerenddateexpirationnotified', 199),
#  ('federallaw', 199),
#  ('verify', 198),
#  ('save', 198),
#  ('signature', 198),
#  ('entitytype', 198),
#  ('storage', 196),
#  ('law', 196),
#  ('schema', 196),
#  ('externalsystem', 196),
#  ('identifier', 196),
#  ('folderdate', 196),
#  ('filemodifytime', 196),
#  ('id1_130_', 195),
#  ('advanced2_130_', 195),
#  ('barcode3_130_', 195),
#  ('costperunit', 195),
#  ('costperunit4_130_', 195),
#  ('costperunitwithoutnds', 195),
#  ('costperunitwithoutnds5_130_', 195),
#  ('creationtime6_130_', 195),
#  ('deleted7_130_', 195),
#  ('description8_130_', 195),
#  ('factmaxvalue', 195),
#  ('factmaxvalue9_130_', 195),
#  ('givingdate10_130_', 195),
#  ('gostclassificationjson11_130_', 195),
#  ('isavailabletoindividuals', 195),
#  ('isavailabletoindividuals12_130_', 195),
#  ('isavailabletoul', 195),
#  ('isavailabletoul13_130_', 195),
#  ('isvisibletostatecustomers', 195),
#  ('isvisibletostatecustomers14_130_', 195),
#  ('maxdays', 195),
#  ('maxdays15_130_', 195),
#  ('maxvalue', 195),
#  ('maxvalue16_130_', 195),
#  ('mindays', 195),
#  ('mindays17_130_', 195),
#  ('minvalue', 195),
#  ('minvalue18_130_', 195),
#  ('modelname19_130_', 195),
#  ('modifycomment', 195),
#  ('modifycomment20_130_', 195),
#  ('modifytime21_130_', 195),
#  ('modifyuserid', 195),
#  ('modifyuserid22_130_', 195),
#  ('name23_130_', 195),
#  ('needreindex24_130_', 195),
#  ('number25_130_', 195),
#  ('offercomment', 195),
#  ('offercomment26_130_', 195),
#  ('offerenddateexpirationnotified27_130_', 195),
#  ('offerparamsjson', 195),
#  ('offerparamsjson28_130_', 195),
#  ('originalname', 195),
#  ('originalname29_130_', 195),
#  ('partnumber30_130_', 195),
#  ('promcooperation', 195),
#  ('promcooperation31_130_', 195),
#  ('serviceperiod', 195),
#  ('serviceperiod32_130_', 195),
#  ('spgzunitmultiplier', 195),
#  ('spgzunitmultiplier33_130_', 195),
#  ('temporarynumber', 195),
#  ('temporarynumber34_130_', 195),
#  ('termsofsupply', 195),
#  ('termsofsupply35_130_', 195),
#  ('valueunlimited', 195),
#  ('valueunlimited36_130_', 195),
#  ('currencyid', 195),
#  ('currencyid37_130_', 195),
#  ('manufacturerid38_130_', 195),
#  ('manufactureroksmid', 195),
#  ('manufactureroksmid39_130_', 195),
#  ('ndsrateid', 195),
#  ('ndsrateid40_130_', 195),
#  ('offerstateid41_130_', 195),
#  ('okeiid42_130_', 195),
#  ('okpdid43_130_', 195),
#  ('oksmid44_130_', 195),
#  ('overpriceid45_130_', 195),
#  ('productionid46_130_', 195),
#  ('productiondirectoryid47_130_', 195),
#  ('replacedbyid', 195),
#  ('replacedbyid48_130_', 195),
#  ('skuid49_130_', 195),
#  ('sourcefileid50_130_', 195),
#  ('spgzid51_130_', 195),
#  ('supplierid52_130_', 195),
#  ('suppliercatalogitemid53_130_', 195),
#  ('userid54_130_', 195),
#  ('getofferpricesjson', 195),
#  ('formula4_', 195),
#  ('dateadd', 195),
#  ('datediff', 195),
#  ('iselectronicexecutionrequired', 192),
#  ('request', 190),
#  ('state', 182),
#  ('fault', 181),
#  ('rabbitmq', 181),
#  ('values', 178),
#  ('skuchanger1_', 177),
#  ('startdate', 174),
#  ('region2_', 173),
#  ('asyncenumerator', 165),
#  ('session', 164),
#  ('thrown', 163),
#  ('supplier1_', 162),
#  ('dbcommand', 161),
#  ('task', 161),
#  ('issmallbusiness', 157),
#  ('p13', 157),
#  ('p14', 157),
#  ('executing', 157),
#  ('invalidoperationexception', 155),
#  ('offeroverprice', 155),
#  ('isoverprice', 155),
#  ('parameters', 155),
#  ('commandtype', 155),
#  ('commandtimeout', 155),
#  ('опросе', 154),
#  ('очереди', 154),
#  ('результатов', 154),
#  ('подписания', 154),
#  ('поставщиком', 154),
#  ('ienumerable', 152),
#  ('isblocked', 151),
#  ('isessionimplementor', 146),
#  ('datascope', 146),
#  ('commit', 145),
#  ('splitqueryingenumerable', 145),
#  ('импорта', 142),
#  ('auctionbet', 142),
#  ('datetime', 141),
#  ('xx', 140),
#  ('consumer', 139),
#  ('p18', 138),
#  ('tstate', 136),
#  ('y5_', 135),
#  ('прямой', 134),
#  ('закуки', 134),
#  ('отстуствует', 134),
#  ('фз_x000d_', 134),
#  ('validate', 134),
#  ('55_x000d_', 134),
#  ('26_x000d_', 134),
#  ('c__displayclass3_0', 134),
#  ('iinterceptor', 134),
#  ('inter', 134),
#  ('38_x000d_', 134),
#  ('linq', 134),
#  ('enumerable', 134),
#  ('tsource', 134),
#  ('source', 134),
#  ('predicate', 134),
#  ('43_x000d_', 134),
#  ('invokeinterceptor', 134),
#  ('entityentry', 134),
#  ('entry', 134),
#  ('ientitypersister', 134),
#  ('persister', 134),
#  ('handleinterception', 134),
#  ('scheduleupdate', 134),
#  ('onflushentity', 134),
#  ('flushentities', 134),
#  ('flusheverythingtoexecutions', 134),
#  ('defaultflusheventlistener', 134),
#  ('onflush', 134),
#  ('flush', 134),
#  ('beforetransactioncompletion', 134),
#  ('itransaction', 134),
#  ('tx', 134),
#  ('adotransaction', 134),
#  ('dispose', 134),
#  ('получения', 134),
#  ('size', 133),
#  ('skuchangerequest', 133),
#  ('файлов', 132),
#  ('каталога', 132),
#  ('nsi', 132),
#  ('справочника', 132),
#  ('classifierimportresultevent', 132),
#  ('companyblock', 132),
#  ('nullable', 130),
#  ('lastbetid', 129),
#  ('события', 126),
#  ('avg', 126),
#  ('cost', 126),
#  ('relationalcommand', 122),
#  ('relationalcommandparameterobject', 122),
#  ('parameterobject', 122),
#  ('publicapi', 119),
#  ('shared', 117),
#  ('n', 116),
#  ('threading', 114),
#  ('executereaderasync', 114),
#  ('skuchanger0_', 111),
#  ('dbtype', 107),
#  ('enumerator', 104),
#  ('уас', 104),
#  ('reverting', 104),
#  ('using', 103),
#  ('context', 100),
#  ('sqlcommand', 98),
#  ('ежедневная', 98),
#  ('выгрузка', 98),
#  ('контрактов', 98),
#  ('закупок', 98),
#  ('supplierca3_', 96),
#  ('amount', 96),
#  ('okpd', 96),
#  ('requesttype', 96),
#  ('need3_', 92),
#  ('message', 92),
#  ('ru', 92),
#  ('runbehavior', 90),
#  ('results', 88),
#  ('y6_', 87),
#  ('y7_', 87),
#  ('typeid', 87),
#  ('supplierca2_', 87),
#  ('невозможно', 87),
#  ('mnemonic', 86),
#  ('hasnmck', 85),
#  ('stack', 85),
#  ('trace', 85),
#  ('executeasync', 84),
#  ('upt24', 84),
#  ('проверка', 84),
#  ('приглашений', 84),
#  ('iterating', 83),
#  ('tasks', 83),
#  ('events', 83),
#  ('tdsparserstateobject', 81),
#  ('connection', 81),
#  ('executioncontext', 81),
#  ('spuser2_', 80),
#  ('purchasesubscription', 80),
#  ('set', 76),
#  ('skuchangerequestid', 73),
#  ('monthyear', 70),
#  ('regioncode', 70),
#  ('skuchanger2_', 70),
#  ('commands', 70),
#  ('batch', 69),
#  ('creationsourceid', 69),
#  ('r', 69),
#  ('sqlserver', 68),
#  ('sqlserverexecutionstrategy', 68),
#  ('tresult', 68),
#  ('verifysucceeded', 68),
#  ('пользователя', 66),
#  ('application', 66),
#  ('keycloak', 66),
#  ('изменения', 65),
#  ('сброса', 65),
#  ('кеша', 65),
#  ('y4_', 65),
#  ('csspcontext', 65),
#  ('p', 65),
#  ('value', 64),
#  ('sendneedinvitationscommand', 64),
#  ('isdemandedmanually', 63),
#  ('noreply', 63),
#  ('sqldatareader', 62),
#  ('previous', 62),
#  ('nmck', 61),
#  ('createuserlogin', 61),
#  ('обработке', 61),
#  ('sqlexception', 60),
#  ('started', 60),
#  ('updatedate', 59),
#  ('импортировать', 59),
#  ('movenextasync', 59),
#  ('location', 58),
#  ('bit', 58),
#  ('proposalstartdate', 58),
#  ('updateuserlogin', 57),
#  ('user', 56),
#  ('response', 56),
#  ('already', 56),
#  ('cannot', 56),
#  ('errordetails', 56),
#  ('работа', 56),
#  ('p15', 55),
#  ('contractst0_', 54),
#  ('initializereaderasync', 53),
#  ('processing', 53),
#  ('isdemanded', 52),
#  ('найдена', 52),
#  ('spusers2_', 52),
#  ('org', 52),
#  ('admin', 52),
#  ('adminevent', 52),
#  ('компания', 51),
#  ('идентификатором', 51),
#  ('актуализации', 51),
#  ('блокировок', 51),
#  ('company__t3_', 51),
#  ('insert', 49),
#  ('запросить', 49),
#  ('stateobj', 48),
#  ('production', 48),
#  ('p4_', 48),
#  ('id1_66_', 47),
#  ('avgprice', 47),
#  ('avgprice2_66_', 47),
#  ('barcode3_66_', 47),
#  ('creationsourceid4_66_', 47),
#  ('description5_66_', 47),
#  ('equivalentgroupid', 47),
#  ('equivalentgroupid6_66_', 47),
#  ('externalsystemid7_66_', 47),
#  ('gostclassificationjson8_66_', 47),
#  ('innovationspgzid', 47),
#  ('innovationspgzid9_66_', 47),
#  ('isdemanded10_66_', 47),
#  ('isdemandedmanually11_66_', 47),
#  ('ismanualapplieddomestic', 47),
#  ('ismanualapplieddomestic12_66_', 47),
#  ('isutility', 47),
#  ('isutility13_66_', 47),
#  ('maxprice', 47),
#  ('maxprice14_66_', 47),
#  ('medianprice', 47),
#  ('medianprice15_66_', 47),
#  ('minprice', 47),
#  ('minprice16_66_', 47),
#  ('modelname17_66_', 47),
#  ('name18_66_', 47),
#  ('needreindex19_66_', 47),
#  ('nmck20_66_', 47),
#  ('offercount21_66_', 47),
#  ('partnumber22_66_', 47),
#  ('recommendedsku', 47),
#  ('recommendedsku23_66_', 47),
#  ('referenceprice', 47),
#  ('referenceprice24_66_', 47),
#  ('skuparamsjson', 47),
#  ('skuparamsjson25_66_', 47),
#  ('views', 47),
#  ('views26_66_', 47),
#  ('willbearchived27_66_', 47),
#  ('manufacturerid28_66_', 47),
#  ('okeiid29_66_', 47),
#  ('oksmid30_66_', 47),
#  ('originuserid', 47),
#  ('originuserid31_66_', 47),
#  ('productiondirectoryid32_66_', 47),
#  ('sourcefileid33_66_', 47),
#  ('spgzid34_66_', 47),
#  ('createdate35_66_', 47),
#  ('createuserlogin36_66_', 47),
#  ('updatedate37_66_', 47),
#  ('updateuserlogin38_66_', 47),
#  ('entitystate39_66_', 47),
#  ('cancelled', 45),
#  ('bl', 45),
#  ('действия', 45),
#  ('nocount', 44),
#  ('удалось', 44),
#  ('p16', 44),
#  ('need0_', 44),
#  ('контракта', 44),
#  ('tdsparser', 42),
#  ('спгз', 42),
#  ('contract4_', 42),
#  ('файл', 41),
#  ('registrationdate', 41),
#  ('operationtype', 40),
#  ('1ms', 40),
#  ('companyrol0_', 40),
#  ('purchasere0_', 40),
#  ('componentmodel', 39),
#  ('win32exception', 39),
#  ('0x80131904', 39),
#  ('clientconnectionid', 39),
#  ('production2_', 39),
#  ('deleteuserbykeycloakid', 39),
#  ('time', 39),
#  ('realmid', 39),
#  ('authdetails', 39),
#  ('clientid', 39),
#  ('ipaddress', 39),
#  ('resourcetype', 39),
#  ('resourcepath', 39),
#  ('plandate', 38),
#  ('int32', 37),
#  ('database', 37),
#  ('createddate', 37),
#  ('кпгз', 37),
#  ('statement', 37),
#  ('terminated', 37),
#  ('queryparameters', 36),
#  ('updateddate', 36),
#  ('2ms', 36),
#  ('p17', 36),
#  ('p20', 36),
#  ('p21', 36),
#  ('skuchangerequesthistory', 36),
#  ('newstateid', 36),
#  ('cust1_', 36),
#  ('consumers', 35),
#  ('kalugaastral', 35),
#  ('class', 34),
#  ('entityrefid', 34),
#  ('extension_4_', 34),
#  ('supplierfo1_', 34),
#  ('machinereadablepowerofattorney', 33),
#  ('company2_', 33),
#  ('externalid', 32),
#  ('querycontext', 31),
#  ('kpp', 31),
#  ('ogrn', 31),
#  ('jobstatus', 30),
#  ('jobs', 30),
#  ('maxdate', 30),
#  ('deletedids', 30),
#  ('reindexids', 30),
#  ('invalid', 30),
#  ('dbdatareader', 30),
#  ('splitqueryresultcoordinator', 30),
#  ('найден', 30),
#  ('contracts3_', 30),
#  ('closure', 29),
#  ('resultcontext', 29),
#  ('taskcanceledexception', 29),
#  ('canceled', 29),
#  ('asyncwrite', 28),
#  ('rowcount', 28),
#  ('найдены', 28),
#  ('запросу', 28),
#  ('busrequests', 28),
#  ('itembykeyrequest', 28),
#  ('getalldocsresponse', 28),
#  ('инфогород', 28),
#  ('регистрация', 28),
#  ('сведений', 28),
#  ('организации', 28),
#  ('аис', 28),
#  ('пп', 28),
#  ('жалобами', 28),
#  ('гарантия', 28),
#  ('банковской', 28),
#  ('гарантией', 28),
#  ('заявкой', 28),
#  ('логистику', 28),
#  ('executedbdatareaderasync', 27),
#  ('b__188_0', 27),
#  ('result', 27),
#  ('continuationresulttaskfromresulttask', 27),
#  ('innerinvoke', 27),
#  ('runinternal', 27),
#  ('contextcallback', 27),
#  ('callback', 27),
#  ('executewiththreadlocal', 27),
#  ('currenttaskslot', 27),
#  ('thread', 27),
#  ('threadpoolthread', 27),
#  ('скачать', 26),
#  ('ссылке', 26),
#  ('1_x000d_', 26),
#  ('powers', 25),
#  ('movenext', 25),
#  ('update', 25),
#  ('registrationnumber', 25),
#  ('mailstodelete', 25),
#  ('offer4_', 24),
#  ('guid', 24),
#  ('jsondata', 24),
#  ('userachievement', 24),
#  ('archived', 24),
#  ('irelationalconnection', 24),
#  ('statemanager', 24),
#  ('savechangesasync', 24),
#  ('supplier0_', 24),
#  ('companyrequest', 24),
#  ('requesttypeid', 24),
#  ('readonlycsspcontext', 24),
#  ('commandbehavior', 24),
#  ('stat', 24),
#  ('collection', 24),
#  ('roleid', 23),
#  ('inretry', 22),
#  ('ds', 22),
#  ('инновационное', 22),
#  ('endfilingdate', 22),
#  ('registernumber', 22),
#  ('офертой', 22),
#  ('контрактом', 22),
#  ('исполнения', 22),
#  ('предложение', 22),
#  ('коммерческим', 22),
#  ('предложением', 22),
#  ('draftcompa1_', 22),
#  ('throwexceptionandwarning', 21),
#  ('callerhasconnectionlock', 21),
#  ('asyncclose', 21),
#  ('cmdhandler', 21),
#  ('datastream', 21),
#  ('bulkcopysimpleresultset', 21),
#  ('bulkcopyhandler', 21),
#  ('_x0002_', 21),
#  ('hexadecimal', 21),
#  ('0x02', 21),
#  ('character', 21),
#  ('alexandrin', 21),
#  ('registrationdatefrom', 21),
#  ('registrationdateto', 21),
#  ('sendresult', 21),
#  ('auctionbet3_', 21),
#  ('запрашиваем', 20),
#  ('дополнительно', 20),
#  ('авторизации', 20),
#  ('интеграционном', 20),
#  ('апи', 20),
#  ('login', 20),
#  ('password', 20),
#  ('case_x000d_', 20),
#  ('initiatedbycompanyid', 20),
#  ('systemuser4_', 20),
#  ('socr', 20),
#  ('пакет', 19),
#  ('импортирован', 19),
#  ('p19', 19),
#  ('p22', 19),
#  ('p23', 19),
#  ('p24', 19),
#  ('p25', 19),
#  ('p26', 19),
#  ('p27', 19),
#  ('p28', 19),
#  ('servertime', 19),
#  ('typename', 18),
#  ('skuimportjob', 18),
#  ('getdate', 18),
#  ('tryrun', 18),
#  ('dataready', 18),
#  ('batchexecutor', 18),
#  ('commandbatches', 18),
#  ('acceptallchangesonsuccess', 18),
#  ('synchronize', 18),
#  ('поиске', 18),
#  ('неиндексированных', 18),
#  ('supplier3_', 18),
#  ('spgzcharac2_', 18),
#  ('характеристики', 17),
#  ('неактуального', 17),
#  ('мчд', 17),
#  ('p29', 17),
#  ('p30', 17),
#  ('p31', 17),
#  ('p32', 17),
#  ('p33', 17),
#  ('p34', 17),
#  ('p35', 17),
#  ('p36', 17),
#  ('p37', 17),
#  ('p38', 17),
#  ('p39', 17),
#  ('p40', 17),
#  ('p41', 17),
#  ('p42', 17),
#  ('p43', 17),
#  ('p44', 17),
#  ('p45', 17),
#  ('p46', 17),
#  ('p47', 17),
#  ('p48', 17),
#  ('p49', 17),
#  ('p50', 17),
#  ('p51', 17),
#  ('p52', 17),
#  ('p53', 17),
#  ('p54', 17),
#  ('p55', 17),
#  ('p56', 17),
#  ('p57', 17),
#  ('p58', 17),
#  ('p59', 17),
#  ('p60', 17),
#  ('p61', 17),
#  ('p62', 17),
#  ('p63', 17),
#  ('p64', 17),
#  ('p65', 17),
#  ('p66', 17),
#  ('y8_', 17),
#  ('y9_', 17),
#  ('y10_', 17),
#  ('y11_', 17),
#  ('y12_', 17),
#  ('y13_', 17),
#  ('y14_', 17),
#  ('isofferauctionblocked', 17),
#  ('y15_', 17),
#  ('promcooperationcompany', 17),
#  ('y16_', 17),
#  ('current_timestamp', 17),
#  ('y17_', 17),
#  ('productiondirectorytrustedsupplier', 17),
#  ('y18_', 17),
#  ('companytype', 17),
#  ('entityref', 17),
#  ('col_2_0_', 17),
#  ('col_3_0_', 17),
#  ('rowversion', 16),
#  ('upload', 16),
#  ('files', 16),
#  ('contractactions', 16),
#  ('contractactionaddedevent', 16),
#  ('needsupplier', 16),
#  ('p67', 16),
#  ('p68', 16),
#  ('p69', 16),
#  ('p70', 16),
#  ('p71', 16),
#  ('p72', 16),
#  ('p73', 16),
#  ('p74', 16),
#  ('p75', 16),
#  ('p76', 16),
#  ('p77', 16),
#  ('p78', 16),
#  ('p79', 16),
#  ('p80', 16),
#  ('p81', 16),
#  ('p82', 16),
#  ('p83', 16),
#  ('p84', 16),
#  ('p85', 16),
#  ('p86', 16),
#  ('p87', 16),
#  ('p88', 16),
#  ('p89', 16),
#  ('p90', 16),
#  ('p91', 16),
#  ('p92', 16),
#  ('p93', 16),
#  ('p94', 16),
#  ('p95', 16),
#  ('p96', 16),
#  ('p97', 16),
#  ('p98', 16),
#  ('p99', 16),
#  ('p100', 16),
#  ('p101', 16),
#  ('p102', 16),
#  ('p103', 16),
#  ('p104', 16),
#  ('p105', 16),
#  ('p106', 16),
#  ('p107', 16),
#  ('p108', 16),
#  ('p109', 16),
#  ('p110', 16),
#  ('p111', 16),
#  ('p112', 16),
#  ('p113', 16),
#  ('p114', 16),
#  ('p115', 16),
#  ('p116', 16),
#  ('p117', 16),
#  ('p118', 16),
#  ('p119', 16),
#  ('p120', 16),
#  ('p121', 16),
#  ('p122', 16),
#  ('p123', 16),
#  ('p124', 16),
#  ('p125', 16),
#  ('p126', 16),
#  ('p127', 16),
#  ('p128', 16),
#  ('p129', 16),
#  ('p130', 16),
#  ('p131', 16),
#  ('p132', 16),
#  ('p133', 16),
#  ('p134', 16),
#  ('p135', 16),
#  ('p136', 16),
#  ('p137', 16),
#  ('p138', 16),
#  ('p139', 16),
#  ('p140', 16),
#  ('p141', 16),
#  ('p142', 16),
#  ('p143', 16),
#  ('p144', 16),
#  ('p145', 16),
#  ('p146', 16),
#  ('p147', 16),
#  ('p148', 16),
#  ('p149', 16),
#  ('p150', 16),
#  ('p151', 16),
#  ('p152', 16),
#  ('p153', 16),
#  ('p154', 16),
#  ('p155', 16),
#  ('p156', 16),
#  ('p157', 16),
#  ('p158', 16),
#  ('p159', 16),
#  ('p160', 16),
#  ('cmdbehavior', 16),
#  ...]

# %%
vocab = build_vocab(counter)

# %%
len(vocab)
# Out:
# 1884

# %%
def process_sent(sent, vocab=vocab):
    sent = replace_parameters(sent)
    tokenized = tokenize(sent.lower())
    cleaned = remove_words(tokenized)
    vocabed = [word for word in cleaned if word in vocab]
    return ' '.join(vocabed)

# %%
data['clean_logs'] = data['log'].apply(process_sent)

# %%
len(data['clean_logs'].unique())
# Out:
# 372

# %%
data['clean_logs'].value_counts()
# Out:
# данные могут проимпортированы причине импортирована поздняя версия сущности packageguid packagedatetime                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             44299
# ошибка обработки запроса регистрацию изменение данных компании id type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               6403
# wait operation timed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 5031
# execution timeout expired timeout period elapsed prior completion operation server responding                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        4996
# pp3 contracts dto contract action contractactionexception автоматическому отказу разрешено                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           3458
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# opcomplete errors error received auction pp auction found ppauctionid message auctionid externalid createddate startdate operationid                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# failed executing dbcommand parameters p1 size p2 size p3 p4 p5 size p6 nullable size p7 nullable size p8 nullable p9 size p10 p11 size commandtype commandtimeout _x000d_ set nocount _x000d_ insert searchlogtemplate id application createuserlogin createddate deleted jsondata name searchtemplate stateid updateuserlogin updateddate url _x000d_ values p0 p1 p2 p3 p4 p5 p6 p7 p8 p9 p10 p11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# could execute command need set needreindex id p1 p2 p3 p4 p5 p6 p7 p8 p9 p10 p11 p12 p13 p14 p15 p16 p17 p18 p19 p20 p21 p22 p23 p24 p25 p26 p27 p28 p29 p30 p31 p32 p33 p34 p35 p36 p37 p38 p39 p40 p41 p42 p43 p44 p45 p46 p47 p48 p49 p50 p51 p52 p53 p54 p55 p56 p57 p58 p59 p60 p61 p62 p63 p64 p65 p66 p67 p68 p69 p70 p71 p72 p73 p74 p75 p76 p77 p78 p79 p80 p81 p82 p83 p84 p85 p86 p87 p88 p89 p90 p91 p92 p93 p94 p95 p96 p97 p98 p99 p100 p101 p102 p103 p104 p105 p106 p107 p108 p109 p110 p111 p112 p113 p114 p115 p116 p117 p118 p119 p120 p121 p122 p123 p124 p125 p126 p127 p128 p129 p130 p131 p132 p133 p134 p135 p136 p137 p138 p139 p140 p141 p142 p143 p144 p145 p146 p147 p148 p149 p150 p151 p152 p153 p154 p155 p156 p157 p158 p159 p160 p161 p162 p163 p164 p165 p166 p167 p168 p169 p170 p171 p172 p173 p174 p175 p176 p177 p178 p179 p180 p181 p182 p183 p184 p185 p186 p187 p188 p189 p190 p191 p192 p193 p194 p195 p196 p197 p198 p199 p200 p201 p202 p203 p204 p205 p206 p207 p208 p209 p210 p211 p212 p213 p214 p215 p216 p217 p218 p219 p220 p221 p222 p223 p224 p225 p226 p227 p228 p229 p230 p231 p232 p233 p234 p235 p236 p237 p238 p239 p240 p241 p242 p243 p244 p245 p246 p247 p248 p249 p250 p251 p252 p253 p254 p255 p256 p257 p258 p259 p260 p261 p262 p263 p264 p265 p266 p267 p268 p269 p270 p271 p272 p273 p274 p275 p276 p277 p278 p279 p280 p281 p282 p283 p284 p285 p286 p287 p288 p289 p290 p291 p292 p293 p294 p295 p296 p297 p298 p299 p300 p301 p302 p303 p304 p305 p306 p307        1
# unable set failed command type                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# failed executing dbcommand 1ms parameters commandtype commandtimeout _x000d_ select top id hierarchyleft hierarchylevel hierarchyright _x000d_ customer _x000d_ id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# Name: clean_logs, Length: 372, dtype: int64
